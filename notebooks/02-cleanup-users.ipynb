# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from transaction_analysis.paths import FRAUD_DATASET_DIR

users = pd.read_parquet(
    FRAUD_DATASET_DIR / "preprocessed" / "users.parquet",
    engine="pyarrow",
    dtype_backend="pyarrow",
)

users.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2000 entries, 825 to 1110
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   current_age        2000 non-null   uint8[pyarrow]
#  1   retirement_age     2000 non-null   uint8[pyarrow]
#  2   birth_year         2000 non-null   uint16[pyarrow]
#  3   birth_month        2000 non-null   uint8[pyarrow]
#  4   gender             2000 non-null   dictionary<values=string, indices=int8, ordered=0>[pyarrow]
#  5   address            2000 non-null   string[pyarrow]
#  6   latitude           2000 non-null   double[pyarrow]
#  7   longitude          2000 non-null   double[pyarrow]
#  8   per_capita_income  2000 non-null   decimal32(9, 2)[pyarrow]
#  9   yearly_income      2000 non-null   decimal32(9, 2)[pyarrow]
#  10  total_debt         2000 non-null   decimal32(9, 2)[pyarrow]
#  11  credit_score       2000 non-null   uint16[pyarrow]
# ...
