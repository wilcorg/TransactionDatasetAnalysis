# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

from transaction_analysis.paths import FRAUD_DATASET_DIR

fraud_labels = (
    pd.read_json(FRAUD_DATASET_DIR / "raw" / "train_fraud_labels.json")["target"]
    .rename_axis("id")
    .rename("fraud")
    .to_frame()
)
fraud_labels
# Out:
#          fraud
# id
# 10649266    No
# 23410063    No
# 9316588     No
# 12478022    No
# 9558530     No
# ...        ...
# 14064699    No
# 7676538     No
# 15131030    No
# 17244732    No
# 15151926    No
#
# [8914963 rows x 1 columns]
